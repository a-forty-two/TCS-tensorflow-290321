# %%
# lemma v/s stemming 
# study studies studying studied 
# lemmatization-> reduced words belong to english dictionary 
# stemma-> reduction happens on basis of vectorized pre-built rules, and may not be in english dictions

# lemma-> study
# stemm-> studi

# https://github.com/jedijulia/porter-stemmer/blob/master/stemmer.py

# %%
# Potato is hungry. Shakira is also hungry. She ate the food. 
# Coreference resolution -> SHE -> SHAKIRA 
# Potato is hungry. Shakira is also hungry. Shakira ate the food. 
from google.colab.patches import cv2_imshow
import cv2
img = cv2.imread('nlp pipeline.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1645x773 at 0x7FD83AA9B850>
